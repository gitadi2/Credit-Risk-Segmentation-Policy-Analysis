# %%
# Business Context #
#The objective is to support credit risk and policy teams in evaluating loan approval strategies while controlling default risk.

# Stakeholders #
#- Credit Risk Team
#- Policy & Strategy Team
#- Data & Analytics Team

# Success Metrics #
#- Approval Rate
#- Default Rate
#- Risk Reduction

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("../data/raw/loan_data_raw.csv")

# %%
df['Status'].value_counts(normalize=True) * 100
# Out:
# Status
# 0    75.355485
# 1    24.644515
# Name: proportion, dtype: float64
